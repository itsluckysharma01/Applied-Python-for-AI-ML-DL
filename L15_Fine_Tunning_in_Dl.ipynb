# %% [markdown]
# ## What is Fine-Tuning

# %% [markdown]
# Fine-tuning allows a pre-trained model to adapt to a new task. This approach uses the knowledge gained from training a model on a large dataset and applying it to a smaller, domain-specific dataset. Fine-tuning involves adjusting the weights of the model's layers or updating certain parts of the model to improve its performance on the new task.
#
# ![image.png](attachment:image.png)
#
# In fine-tuning, we typically unfreeze some of the layers of the pre-trained model and train them on the new dataset. This process allows the model to learn task-specific features while retaining the general features learned from the original training. Fine-tuning is particularly effective when the new dataset is small, as it leverages the knowledge from the larger dataset to improve performance and reduce overfitting.
#
# Fine-tuning is used in transfer learning where a is model trained on one similar task and is reused for another task often with minimal changes. The underlying assumption is that the model has already learned useful features in the original task that can be transferred and adapted to the new task hence reducing the need for training a model from scratch.
#
# ## Working of Fine-Tuning
#
# * **Select a Pre-Trained Model:** The first step is to choose a pre-trained model that has been trained on a large, diverse dataset. Popular pre-trained models includes BERT for NLP tasks, VGG and ResNet for image classification tasks and GPT models for text generation.
# * **Freeze Initial Layers:** In fine-tuning we usually freeze the weights of the earlier layers in the model. These layers capture basic features like edges or textures in images or simple words in text. Freezing these layers reduces the computational load as only the later layers will be trained.
# * **Update Later Layers:** The later layers of the model are the ones that specialize in more specific features. These layers are typically fine-tuned to adjust the weights based on the new task. For example if we're fine-tuning a language model for sentiment analysis then the final layers will adjust to classify the sentiment of the input text.
# * **Use a Smaller Learning Rate:** A key principle in fine-tuning is using a smaller learning rate compared to training from scratch. This ensures that the pre-trained weights are not drastically changed but are adjusted just enough to perform well on the new task.
# * **Evaluate and Refine:** After training it's important to evaluate the performance of the fine-tuned model on the specific task. Based on the evaluation we may continue to adjust the learning rate, fine-tune more layers or apply other modifications until the model performs optimally.
#
# ## Applications
#
# * **Image Classification:** Fine-tuning is widely used in image classification tasks, allowing models to leverage pre-trained features for improved accuracy and efficiency.
# * **Natural Language Processing (NLP):** In NLP, fine-tuning enables models to understand language patterns and semantics, enhancing performance in tasks like sentiment analysis and machine translation.
# * **Medical Imaging:** Fine-tuning is crucial in medical imaging, where it helps models learn from limited data to identify diseases and anomalies, improving diagnostic accuracy.
# * **Speech Recognition:** Fine-tuning allows speech recognition models to adapt to different languages and accents, enhancing their versatility and performance in real-world applications.
